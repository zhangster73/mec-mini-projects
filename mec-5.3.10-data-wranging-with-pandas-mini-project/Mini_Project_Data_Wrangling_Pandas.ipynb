# %% [markdown]
# # Mini-Project: Data Wrangling and Transformation with Pandas
#
# Working with tabular data is a necessity for anyone with enterprises having a majority of their data in relational databases and flat files. This mini-project is adopted from the excellent tutorial on pandas by Brandon Rhodes which you have watched earlier in the Data Wrangling Unit. In this mini-project, we will be looking at some interesting data based on movie data from the IMDB.
#
# This assignment should help you reinforce the concepts you learnt in the curriculum for Data Wrangling and sharpen your skills in using Pandas. Good Luck!

# %% [markdown]
# ### Please make sure you have one of the more recent versions of Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pd.__version__
# Out:
# '0.24.2'

# %% [markdown]
# ## Taking a look at the Movies dataset
# This data shows the movies based on their title and the year of release

# %%
movies = pd.read_csv('titles.csv')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244914 entries, 0 to 244913
# Data columns (total 2 columns):
# title    244914 non-null object
# year     244914 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 3.7+ MB

# %%
movies.head()
# Out:
#                                           title  year
# 0                        The Ticket to the Life  2009
# 1  Parallel Worlds: A New Rock Music Experience  2016
# 2                     Morita - La hija de Jesus  2008
# 3                                           Gun  2017
# 4                        Love or Nothing at All  2014

# %% [markdown]
# ## Taking a look at the Cast dataset
#
# This data shows the cast (actors, actresses, supporting roles) for each movie
#
# - The attribute `n` basically tells the importance of the cast role, lower the number, more important the role.
# - Supporting cast usually don't have any value for `n`

# %%
cast = pd.read_csv('cast.csv.zip')
cast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3786176 entries, 0 to 3786175
# Data columns (total 6 columns):
# title        object
# year         int64
# name         object
# type         object
# character    object
# n            float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 173.3+ MB

# %%
cast.head(10)
# Out:
#                                                title  year  \
# 0                                     Closet Monster  2015
# 1                                    Suuri illusioni  1985
# 2                                Battle of the Sexes  2017
# 3                               Secret in Their Eyes  2015
# 4                                         Steve Jobs  2015
# 5                             Straight Outta Compton  2015
# 6                             Straight Outta Compton  2015
# 7                                     For Thy Love 2  2009
# 8  Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                       Desire (III)  2014
#
#                         name   type                               character  \
# 0                   Buffy #1  actor                                 Buffy 4
# 1                     Homo $  actor                                  Guests
# 2                    $hutter  actor                         Bobby Riggs Fan
# ...

# %% [markdown]
# ## Taking a look at the Release dataset
#
# This data shows details of when each movie was release in each country with the release date

# %%
release_dates = pd.read_csv('release_dates.csv', parse_dates=['date'], infer_datetime_format=True)
release_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479488 entries, 0 to 479487
# Data columns (total 4 columns):
# title      479488 non-null object
# year       479488 non-null int64
# country    479488 non-null object
# date       479488 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 14.6+ MB

# %%
release_dates.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                   #BKKY  2016     Cambodia 2017-10-12
# 2                 #Beings  2015      Romania 2015-01-29
# 3               #Captured  2017          USA 2017-09-05
# 4  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21

# %% [markdown]
# # Section I - Basic Querying, Filtering and Transformations

# %% [markdown]
# ### What is the total number of movies?

# %%
len(movies)
# Out:
# 244914

# %% [markdown]
# ### List all Batman movies ever made

# %%
batman_df = movies[movies.title == 'Batman']
print('Total Batman Movies:', len(batman_df))
batman_df
# Out:
# Total Batman Movies: 2
#          title  year
# 52734   Batman  1943
# 150621  Batman  1989

# %% [markdown]
# ### List all Batman movies ever made - the right approach

# %%
batman_df = movies[movies.title.str.contains('Batman', case=False)]
print('Total Batman Movies:', len(batman_df))
batman_df.head(10)
# Out:
# Total Batman Movies: 35
#                                              title  year
# 16813                              Batman: Anarchy  2016
# 30236                               Batman Forever  1995
# 31674                                Batman Untold  2010
# 31711  Scooby-Doo & Batman: the Brave and the Bold  2018
# 41881                  Batman the Rise of Red Hood  2018
# 43484        Batman: Return of the Caped Crusaders  2016
# 46333                               Batman & Robin  1997
# 51811                              Batman Revealed  2012
# 52734                                       Batman  1943
# 56029                 Batman Beyond: Rising Knight  2014

# %% [markdown]
# ### Display the top 15 Batman movies in the order they were released

# %%
batman_df.sort_values(by=['year'], ascending=True).iloc[:15]
# Out:
#                                title  year
# 52734                         Batman  1943
# 100056              Batman and Robin  1949
# 161439                Batman Dracula  1964
# 84327          Alyas Batman at Robin  1965
# 68364                   James Batman  1966
# 161527             Batman: The Movie  1966
# 56159          Batman Fights Dracula  1967
# 168504         Fight! Batman, Fight!  1973
# 150621                        Batman  1989
# 156239         Alyas Batman en Robin  1991
# 156755                Batman Returns  1992
# 63366   Batman: Mask of the Phantasm  1993
# 30236                 Batman Forever  1995
# 46333                 Batman & Robin  1997
# 208220                 Batman Begins  2005

# %% [markdown]
# ### Section I - Q1 : List all the 'Harry Potter' movies from the most recent to the earliest

# %%
harrypotter_df = movies[movies.title.str.contains('Harry Potter', case=False)]
harrypotter_df.sort_values(by=['year'], ascending=False)
# Out:
#                                                title  year
# 143147  Harry Potter and the Deathly Hallows: Part 2  2011
# 152831  Harry Potter and the Deathly Hallows: Part 1  2010
# 109213        Harry Potter and the Half-Blood Prince  2009
# 50581      Harry Potter and the Order of the Phoenix  2007
# 187926           Harry Potter and the Goblet of Fire  2005
# 61957       Harry Potter and the Prisoner of Azkaban  2004
# 82791        Harry Potter and the Chamber of Secrets  2002
# 223087         Harry Potter and the Sorcerer's Stone  2001

# %% [markdown]
# ### How many movies were made in the year 2017?

# %%
len(movies[movies.year == 2017])
# Out:
# 11474

# %% [markdown]
# ### Section I - Q2 : How many movies were made in the year 2015?

# %%
len(movies[movies.year == 2015])
# Out:
# 8702

# %% [markdown]
# ### Section I - Q3 : How many movies were made from 2000 till 2018?
# - You can chain multiple conditions using OR (`|`) as well as AND (`&`) depending on the condition

# %%
len(movies[(movies.year >= 2000) & (movies.year <= 2018)])
# Out:
# 114070

# %% [markdown]
# ### Section I - Q4: How many movies are titled "Hamlet"?

# %%
len(movies[movies['title']=='Hamlet'])
# Out:
# 20

# %% [markdown]
# ### Section I - Q5: List all movies titled "Hamlet"
# - The movies should only have been released on or after the year 2000
# - Display the movies based on the year they were released (earliest to most recent)

# %%
hamlet_df = movies[(movies['title']=='Hamlet') & (movies['year'] >=2000)]
hamlet_df.sort_values(by='year', ascending=True)
# Out:
#          title  year
# 55639   Hamlet  2000
# 1931    Hamlet  2009
# 227953  Hamlet  2011
# 178290  Hamlet  2014
# 186137  Hamlet  2015
# 191940  Hamlet  2016
# 244747  Hamlet  2017

# %% [markdown]
# ### Section I - Q6: How many roles in the movie "Inception" are of the supporting cast (extra credits)
# - supporting cast are NOT ranked by an "n" value (NaN)
# - check for how to filter based on nulls

# %%
inception_cast = cast[cast['title'] == 'Inception']
len(inception_cast[inception_cast['n'].isna()])
# Out:
# 27

# %% [markdown]
# ### Section I - Q7: How many roles in the movie "Inception" are of the main cast
# - main cast always have an 'n' value

# %%
len(inception_cast[inception_cast['n'].notnull()])
# Out:
# 51

# %% [markdown]
# ### Section I - Q8: Show the top ten cast (actors\actresses) in the movie "Inception"
# - main cast always have an 'n' value
# - remember to sort!

# %%
inception_cast.sort_values(by='n', ascending=True).iloc[0:10]
# Out:
#              title  year                  name     type        character     n
# 590576   Inception  2010     Leonardo DiCaprio    actor             Cobb   1.0
# 859993   Inception  2010  Joseph Gordon-Levitt    actor           Arthur   2.0
# 3387147  Inception  2010            Ellen Page  actress          Ariadne   3.0
# 940923   Inception  2010             Tom Hardy    actor            Eames   4.0
# 2406531  Inception  2010          Ken Watanabe    actor            Saito   5.0
# 1876301  Inception  2010            Dileep Rao    actor            Yusuf   6.0
# 1615709  Inception  2010        Cillian Murphy    actor   Robert Fischer   7.0
# 183937   Inception  2010          Tom Berenger    actor         Browning   8.0
# 2765969  Inception  2010      Marion Cotillard  actress              Mal   9.0
# 1826027  Inception  2010    Pete Postlethwaite    actor  Maurice Fischer  10.0

# %% [markdown]
# ### Section I - Q9:
#
# (A) List all movies where there was a character 'Albus Dumbledore'
#
# (B) Now modify the above to show only the actors who played the character 'Albus Dumbledore'
# - For Part (B) remember the same actor might play the same role in multiple movies

# %%
cast[cast['character'] == 'Albus Dumbledore']
# Out:
#                                              title  year                 name  \
# 704984                                  Epic Movie  2007         Dane Farwell
# 792421         Harry Potter and the Goblet of Fire  2005       Michael Gambon
# 792423   Harry Potter and the Order of the Phoenix  2007       Michael Gambon
# 792424    Harry Potter and the Prisoner of Azkaban  2004       Michael Gambon
# 947789     Harry Potter and the Chamber of Secrets  2002       Richard Harris
# 947790       Harry Potter and the Sorcerer's Stone  2001       Richard Harris
# 1685537                      Ultimate Hero Project  2013  George (X) O'Connor
# 2248085                                     Potter  2015    Timothy Tedmanson
#
#           type         character     n
# 704984   actor  Albus Dumbledore  17.0
# 792421   actor  Albus Dumbledore  37.0
# 792423   actor  Albus Dumbledore  36.0
# 792424   actor  Albus Dumbledore  27.0
# 947789   actor  Albus Dumbledore  32.0
# ...

# %%
cast[cast['character'] == 'Albus Dumbledore'].drop_duplicates(subset='name')
# Out:
#                                            title  year                 name  \
# 704984                                Epic Movie  2007         Dane Farwell
# 792421       Harry Potter and the Goblet of Fire  2005       Michael Gambon
# 947789   Harry Potter and the Chamber of Secrets  2002       Richard Harris
# 1685537                    Ultimate Hero Project  2013  George (X) O'Connor
# 2248085                                   Potter  2015    Timothy Tedmanson
#
#           type         character     n
# 704984   actor  Albus Dumbledore  17.0
# 792421   actor  Albus Dumbledore  37.0
# 947789   actor  Albus Dumbledore  32.0
# 1685537  actor  Albus Dumbledore   NaN
# 2248085  actor  Albus Dumbledore   NaN

# %% [markdown]
# ### Section I - Q10:
#
# (A) How many roles has 'Keanu Reeves' played throughout his career?
#
# (B) List the leading roles that 'Keanu Reeves' played on or after 1999 in order by year.

# %%
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
len(cast[cast['name']=='Keanu Reeves'])
# Out:
# 62

# %%
keanureeves_df = cast[cast['name']=='Keanu Reeves']
keanureeves_df[(keanureeves_df['year'] >= 1999) & (keanureeves_df['n']==1)].sort_values(by='year', ascending=True)
# Out:
#                                  title  year          name   type  \
# 1892390                     The Matrix  1999  Keanu Reeves  actor
# 1892397               The Replacements  2000  Keanu Reeves  actor
# 1892358                      Hard Ball  2001  Keanu Reeves  actor
# 1892383                 Sweet November  2001  Keanu Reeves  actor
# 1892348                    Constantine  2005  Keanu Reeves  actor
# 1892388                 The Lake House  2006  Keanu Reeves  actor
# 1892382                   Street Kings  2008  Keanu Reeves  actor
# 1892385  The Day the Earth Stood Still  2008  Keanu Reeves  actor
# 1892359                  Henry's Crime  2010  Keanu Reeves  actor
# 1892342                       47 Ronin  2013  Keanu Reeves  actor
# 1892361                      John Wick  2014  Keanu Reeves  actor
# 1892366                    Knock Knock  2015  Keanu Reeves  actor
# 1892399                The Whole Truth  2016  Keanu Reeves  actor
# ...

# %% [markdown]
# ### Section I - Q11:
#
# (A) List the total number of actor and actress roles available from 1950 - 1960
#
# (B) List the total number of actor and actress roles available from 2007 - 2017

# %%
cast[(cast['year'] >= 1950) & (cast['year'] <= 1960)]
# Out:
# 234635

# %%
cast[(cast['year'] >= 2007) & (cast['year'] <= 2017)]
# Out:
# 1452413

# %% [markdown]
# ### Section I - Q12:
#
# (A) List the total number of leading roles available from 2000 to present
#
# (B) List the total number of non-leading roles available from 2000 - present (exclude support cast)
#
# (C) List the total number of support\extra-credit roles available from 2000 - present

# %%
cast[(cast['year'] >= 2000) & (cast['n'] == 1)]
# Out:
#                                               title  year  \
# 102                          Live Freaky Die Freaky  2006
# 138                           All Things Fall Apart  2011
# 144                                     Freelancers  2012
# 145                          Get Rich or Die Tryin'  2005
# 146                                             Gun  2010
# 154                                           Setup  2011
# 165                                    La hora cero  2010
# 243      Mezhzvyozdnyie voyny. Sila probuzhdayetsya  2015
# 244      Mezhzvyozdnyie voyny. Sila probuzhdayetsya  2015
# 245                                    Mortem (III)  2016
# 258                               Tayna Slendermena  2013
# 259                             Tayna Slendermena 2  2014
# 325                                         Aravaan  2012
# 326                                         Aravaan  2012
# 329                                           Eeram  2009
# ...

# %%
cast[(cast['year'] >= 2000) & (cast['n'] >= 1) & (cast['n'].notnull())]
# Out:
#                                                      title  year  \
# 0                                           Closet Monster  2015
# 2                                      Battle of the Sexes  2017
# 8        Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 10                                 When the Man Went South  2014
# 11                                 Little Angel (Angelita)  2015
# 16                                         My Song for You  2010
# 17                                         My Song for You  2010
# 27                                             De la calle  2001
# 29                                 They Want Dick Dickster  2015
# 30                                        Mahogany Sunrise  2014
# 31                                                 Wakolda  2013
# 39                               Nothing Like the Holidays  2008
# 40                                            Ransum Games  2014
# ...

# %%
cast[(cast['year'] >= 2000) & (cast['n'].isna())]
# Out:
#                                                      title  year  \
# 3                                     Secret in Their Eyes  2015
# 4                                               Steve Jobs  2015
# 5                                   Straight Outta Compton  2015
# 6                                   Straight Outta Compton  2015
# 7                                           For Thy Love 2  2009
# 9                                             Desire (III)  2014
# 13                                        The Replacements  2000
# 14                                    All Out Dysfunktion!  2016
# 15                                                    Gook  2017
# 18                                            Hustle Beach  2017
# 21                                             Todo x Sara  2014
# 22                                        Barrio Gangsters  2009
# 23       Cornmeal, Gunpowder, Ham Hocks and Guitar Strings  2015
# ...

# %% [markdown]
# # Section II - Aggregations, Transformations and Visualizations

# %% [markdown]
# ## What are the top ten most common movie names of all time?

# %%
top_ten = movies.title.value_counts()[:10]
top_ten
# Out:
# Hamlet                  20
# Carmen                  17
# Macbeth                 16
# Maya                    12
# Temptation              12
# The Outsider            12
# Freedom                 11
# Othello                 11
# Honeymoon               11
# The Three Musketeers    11
# Name: title, dtype: int64

# %% [markdown]
# ### Plot the top ten common movie names of all time

# %%
top_ten.plot(kind='barh')

# %% [markdown]
# ### Section II - Q1:  Which years in the 2000s saw the most movies released? (Show top 3)

# %%
most_released = movies[(movies['year'] >= 2000) & (movies['year'] < 2010)].year.value_counts()[:3]
most_released
# Out:
# 2009    6125
# 2008    5151
# 2007    4467
# Name: year, dtype: int64

# %% [markdown]
# ### Section II - Q2: # Plot the total number of films released per-decade (1890, 1900, 1910,....)
# - Hint: Dividing the year and multiplying with a number might give you the decade the year falls into!
# - You might need to sort before plotting

# %%
release_dates['decade'] = (release_dates['year']//10)*10
release_dates.decade.value_counts().plot(kind='barh')

# %% [markdown]
# ### Section II - Q3:
#
# (A) What are the top 10 most common character names in movie history?
#
# (B) Who are the top 10 people most often credited as "Herself" in movie history?
#
# (C) Who are the top 10 people most often credited as "Himself" in movie history?

# %%
cast.name.value_counts()[:10]
# Out:
# Bess Flowers       835
# Herman Hack        702
# Sam (II) Harris    667
# Lee Phelps         624
# Harold Miller      624
# Frank O'Connor     613
# Franklyn Farnum    570
# Tom London         565
# Larry Steers       559
# Frank Ellis        546
# Name: name, dtype: int64

# %%
cast[cast['type'] == 'actress'].name.value_counts()[:10]
# Out:
# Bess Flowers       835
# Aruna Irani        301
# Mary Gordon        286
# Helen              265
# Gertrude Astor     243
# Leonor G?mez       234
# Minerva Urecal     228
# Dorothy Vernon     222
# Suzanne Ridgway    217
# Sukumari           210
# Name: name, dtype: int64

# %%
cast[cast['type'] == 'actor'].name.value_counts()[:10]
# Out:
# Herman Hack        702
# Sam (II) Harris    667
# Harold Miller      624
# Lee Phelps         624
# Frank O'Connor     613
# Franklyn Farnum    570
# Tom London         565
# Larry Steers       559
# Frank Ellis        546
# Bud Osborne        512
# Name: name, dtype: int64

# %% [markdown]
# ### Section II - Q4:
#
# (A) What are the top 10 most frequent roles that start with the word "Zombie"?
#
# (B) What are the top 10 most frequent roles that start with the word "Police"?
#
# - Hint: The `startswith()` function might be useful

# %%
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
cast[cast['character'].str.startswith('Zombie') == True].sort_values(by='n', ascending=True)[:10]
# Out:
#                                   title  year                  name     type  \
# 2669178  2056 Escape from Zombie Island  2012          Annya Bright  actress
# 400724                       Zombie Boy  2015        Matthew Cheney    actor
# 2965317          Last Rites of the Dead  2006         Jenny Greeman  actress
# 2062622          Zombie ja Kummitusjuna  1991          Silu Sepp?l?    actor
# 1176500                      Zombie Cop  1991        Michael Kemper    actor
# 283948   2056 Escape from Zombie Island  2012  Andrew Jeffrey Brown    actor
# 3426137                       I Am Bish  2009        Vanessa Pitrau  actress
# 1370886     The War on the War on Drugs  2002        Yuri Lowenthal    actor
# 82532                    The Angry Nerd  2017     Eric (XII) Arnold    actor
# 3456562                  H1Z1: Infected  2016              Shay Ran  actress
#
#                     character    n
# 2669178                Zombie  1.0
# 400724             Zombie Boy  1.0
# ...

# %%
cast[cast['character'].str.startswith('Police') == True].sort_values(by='n', ascending=True)[:10]
# Out:
#                             title  year               name   type  \
# 213166         The Panther's Claw  1942    Sidney Blackmer  actor
# 2238014  Accadde al commissariato  1954       Nino Taranto  actor
# 845219          Drive In Massacre  1976       John F. Goff  actor
# 1014814      Defenders of the Law  1931  John (II) Holland  actor
# 1019718      Making the Headlines  1938          Jack Holt  actor
# 2279039                  I mostri  1963       Ugo Tognazzi  actor
# 1020153     The Yesterday Machine  1963           Tim Holt  actor
# 17257       How's Your Love Life?  1971          John Agar  actor
# 839286    Murder on a Bridle Path  1936      James Gleason  actor
# 1174122             Parole Racket  1937         Paul Kelly  actor
#
#                                  character    n
# 213166   Police Commissioner Thatcher Colt  1.0
# 2238014                       Police Chief  1.0
# 845219              Police Det. Mike Leary  1.0
# ...

# %% [markdown]
# ### Section II - Q5: Plot how many roles 'Keanu Reeves' has played in each year of his career.

# %%
cast[cast['name'] == 'Keanu Reeves'].year.value_counts()
# Out:
# 2016    5
# 1988    4
# 1993    4
# 2003    3
# 2017    3
# 1986    3
# 1999    3
# 1991    3
# 2000    3
# 2005    3
# 2001    2
# 1996    2
# 1997    2
# 2008    2
# 2006    2
# 1990    2
# 1989    2
# 2013    2
# 1995    2
# 1992    1
# 2019    1
# 1994    1
# 2018    1
# 2009    1
# 2010    1
# 2012    1
# 2014    1
# 2015    1
# 1985    1
# Name: year, dtype: int64

# %% [markdown]
# ### Section II - Q6: Plot the cast positions (n-values) of Keanu Reeve's roles through his career over the years.

# %%
keanu_positions = cast[cast['name'] == 'Keanu Reeves']
keanu_positions = keanu_positions.sort_values('year')
plt.plot(keanu_positions['year'], keanu_positions['n'])

# %% [markdown]
# ### Section II - Q7: Plot the number of "Hamlet" films made by each decade

# %%
release_dates['decade'] = (release_dates['year']//10)*10
release_dates[release_dates['title'] == 'Hamlet'].decade.value_counts().plot(kind='barh')

# %% [markdown]
# ### Section II - Q8:
#
# (A) How many leading roles were available to both actors and actresses, in the 1960s (1960-1969)?
#
# (B) How many leading roles were available to both actors and actresses, in the 2000s (2000-2009)?
#
# - Hint: A specific value of n might indicate a leading role

# %%
len(cast[(cast['year'] >= 1960) & (cast['year'] <1970) & (cast['n'] == 1)])
# Out:
# 11823

# %%
len(cast[(cast['year'] >= 2000) & (cast['year'] <2010) & (cast['n'] == 1)])
# Out:
# 26344

# %% [markdown]
# ### Section II - Q9: List, in order by year, each of the films in which Frank Oz has played more than 1 role.

# %%
frankoz_df = cast[cast['name'] == 'Frank Oz']
frankoz_df[frankoz_df['title'].duplicated(keep=False)].sort_values(by='year')
# Out:
#                                         title  year      name   type  \
# 1723652                      The Muppet Movie  1979  Frank Oz  actor
# 1723651                      The Muppet Movie  1979  Frank Oz  actor
# 1723650                      The Muppet Movie  1979  Frank Oz  actor
# 1723649                      The Muppet Movie  1979  Frank Oz  actor
# 1723648                      The Muppet Movie  1979  Frank Oz  actor
# 1723647                      The Muppet Movie  1979  Frank Oz  actor
# 1723646                      The Muppet Movie  1979  Frank Oz  actor
# 1723645                      The Muppet Movie  1979  Frank Oz  actor
# 1723598        An American Werewolf in London  1981  Frank Oz  actor
# 1723637                The Great Muppet Caper  1981  Frank Oz  actor
# 1723635                The Great Muppet Caper  1981  Frank Oz  actor
# 1723634                The Great Muppet Caper  1981  Frank Oz  actor
# 1723633                The Great Muppet Caper  1981  Frank Oz  actor
# ...

# %% [markdown]
# ### Section II - Q10: List each of the characters that Frank Oz has portrayed at least twice

# %%
frankoz_char = frankoz_df[frankoz_df['title'].duplicated(keep=False)].sort_values(by='year')
frankoz_char['character'].tolist()
# Out:
# ['Motorcycle Guy',
#  'Swedish Chef (assistant)',
#  'Marvin Suggs',
#  "Doc Hopper's Men",
#  'Sam the Eagle',
#  'Animal',
#  'Fozzie Bear',
#  'Miss Piggy',
#  'Mr. Collins',
#  'Swedish Chef',
#  'Sam the Eagle',
#  'Animal',
#  'Fozzie Bear',
#  'Miss Piggy',
#  'Gramps',
#  'Miss Piggy',
#  'Aughra, a Keeper Of Secrets (performer)',
#  'Chamberlain (performer)',
#  'Sam the Eagle',
#  'Cookie Monster',
#  'Bert',
#  'Animal',
#  'Fozzie',
#  'Ocean Breeze Soap Board Member',
#  'Miss Piggy',
#  'Cookie Monster',
#  'Bert',
#  'Grover',
#  'Horse and Carriage Driver',
#  'Vegetable Salesman',
#  'Animal',
#  'Sam the Eagle as Headmaster of Junior High Graduates',
#  'Fozzie Bear as Fozziewig',
#  'Miss Piggy as Emily Cratchit',
#  'George the Janitor',
#  'Animal',
#  'Sam the Eagle',
#  'Fozzie Bear',
#  'Miss Piggy',
#  'Grover',
#  'Miss Piggy',
#  'Fozzie Bear',
#  'Animal',
#  'Sam the Eagle',
#  'Bert',
#  'Cookie Monster']

# %% [markdown]
# # Section III - Advanced Merging, Querying and Visualizations

# %% [markdown]
# ## Make a bar plot with the following conditions
# - Frequency of the number of movies with "Christmas" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by month

# %%
christmas = release_dates[(release_dates.title.str.contains('Christmas')) & (release_dates.country == 'USA')]
christmas.date.dt.month.value_counts().sort_index().plot(kind='bar')

# %% [markdown]
# ### Section III - Q1: Make a bar plot with the following conditions
# - Frequency of the number of movies with "Summer" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by month

# %%
summer = release_dates[(release_dates.title.str.contains('Summer')) & (release_dates.country == 'USA')]
summer.date.dt.month.value_counts().sort_index().plot(kind='bar')

# %% [markdown]
# ### Section III - Q2: Make a bar plot with the following conditions
# - Frequency of the number of movies with "Action" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by week

# %%
action = release_dates[(release_dates.title.str.contains('Action')) & (release_dates.country == 'USA')]
action.date.dt.week.value_counts().sort_index().plot(kind='bar')

# %% [markdown]
# ### Section III - Q3: Show all the movies in which Keanu Reeves has played the lead role along with their   release date in the USA sorted by the date of release
# - Hint: You might need to join or merge two datasets!

# %%
keanureeves = cast[(cast['name'] == 'Keanu Reeves') & (cast['n'] == 1)]
keanureeves = pd.merge(keanureeves, release_dates, how='inner', on='title')
keanureeves[keanureeves['country'] == 'USA'].sort_values(by='date')
# Out:
#                                 title  year_x          name   type  \
# 446                             Speed    1994  Keanu Reeves  actor
# 448                             Speed    1994  Keanu Reeves  actor
# 522                    Sweet November    2001  Keanu Reeves  actor
# 742                  The Night Before    1988  Keanu Reeves  actor
# 78   Bill & Ted's Excellent Adventure    1989  Keanu Reeves  actor
# 69         Bill & Ted's Bogus Journey    1991  Keanu Reeves  actor
# 434                     Little Buddha    1993  Keanu Reeves  actor
# 451                             Speed    1994  Keanu Reeves  actor
# 371                   Johnny Mnemonic    1995  Keanu Reeves  actor
# 49               A Walk in the Clouds    1995  Keanu Reeves  actor
# 91                     Chain Reaction    1996  Keanu Reeves  actor
# 190                 Feeling Minnesota    1996  Keanu Reeves  actor
# 621              The Devil's Advocate    1997  Keanu Reeves  actor
# ...

# %% [markdown]
# ### Section III - Q4: Make a bar plot showing the months in which movies with Keanu Reeves tend to be released in the USA?

# %%
keanureeves = cast[(cast['name'] == 'Keanu Reeves')]
keanureeves = pd.merge(keanureeves, release_dates, how='inner', on='title')
keanureeves = keanureeves[keanureeves['release_dates'] == 'USA']

keanureeves.date.dt.month.value_counts().sort_index().plot(kind='bar')

# %% [markdown]
# ### Section III - Q5: Make a bar plot showing the years in which movies with Ian McKellen tend to be released in the USA?

# %%
ianmckellen = cast[(cast['name'] == 'Ian McKellen')]
ianmckellen = pd.merge(ianmckellen, release_dates, how='inner', on='title')
ianmckellen = ianmckellen[ianmckellen['country'] == 'USA']

ianmckellen.date.dt.month.value_counts().sort_index().plot(kind='bar')
